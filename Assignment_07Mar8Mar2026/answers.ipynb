# %%
import numpy as np
def loss_function(predicted,actual):    
    a = np.array(predicted)
    b = np.array(actual)
    mae = sum(abs(a-b))/len(predicted)
    mse = sum((a-b)**2)/len(predicted)
    rmse = ((sum((a-b)**2)/len(predicted))**0.5)
    print(f"Error=> MAE:{mae} MSE: {mse} RMSE: {rmse}")
    return mae,mse,rmse

# %%
predicted = [10.4, 7.4, 3.6]
actual= [8, 3, 10]
loss_function(predicted,actual)
# Out:
# Error=> MAE:4.4 MSE: 22.02666666666667 RMSE: 4.693257575146145
# (np.float64(4.4), np.float64(22.02666666666667), np.float64(4.693257575146145))
