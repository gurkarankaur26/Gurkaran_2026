# %%
def get_last_digit(num):
    return num%10

# %%
get_last_digit(12345)
# Out:
# 5

# %%
def remove_last_digit(num):
    return num//10

# %%
remove_last_digit(12345)
# Out:
# 1234

# %%
def fit(x1,y1,x2,y2):
    # equation of line with points y = mx +c   
    m:any
    c:any 
    #y1 = m*x1 + c
    #y2 = m*x2 + c
    #y1 -y2 = m*x1 - m*x2 
    #y1-y2 = m(x1-x2)
    m = abs((y1-y2)/(x1-x2))
   # y1 = (abs((y1-y2)/(x1-x2)))*x1 + c
    c = abs(y1 - m*x1)
    return(m,c)

# %%
fit(1, 2, 3, 6)
# Out:
# (2.0, 0.0)

# %%
import math
def square(num):
    return num*num
def cube(x):
    return x * x * x
def sin(x):
    return math.sin(x)

def approx_derivative(func, x, h):
    #h is the small change
    x1= x
    x2=x+h
    y1 = func(x)
    y2 = func(x+h)
    rate_of_change =  abs((y2-y1))/abs(x2-x1)
    return rate_of_change

# %%
approx_derivative(square, 3, 0.0001)
# Out:
# 6.000099999999392

# %%
import random

# %%
def print_random_no(start,end):    
    rno =random.random() # generates random number between 0-1
    num= int(rno*end)
    if num < start:
        print(num+start)
    else:
        print(num)

# %%
print_random_no(5,10)
# Out:
# 9

# %%
def toss_coin():
    rno = random.random() #random no between 0 and 1
    mid = 1/2
    if rno < mid:
        print('Head')
    else:
        print('Tail')

# %%
toss_coin()
# Out:
# Tail

# %%
def my_impurity(c1, c2):    
    impurity_value =0    
    if(c1< c2 and c1 != 0):
        impurity_value = round(c2-c1/c1,2)/10
    elif c2 < c1 and c2 !=0:
        impurity_value= round(c1-c2/c2,2)/10
    print (impurity_value)   
    res=''
    if (c1 == 0 and c2>0) or (c2==0 and c1>0):
        res='Pure and Impurity Value: '+ str(impurity_value)
    else:
        res='Impure and Impurity Value: '+ str(impurity_value)
        
    return res

# %%
my_impurity(9, 1)
# Out:
# 0.9
# 'Impure and Impurity Value: 0.9'
