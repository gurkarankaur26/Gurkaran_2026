# %%
def closer_point(p, a, b):
    x1 = p[0]
    y1 = p[1]
    x2 = a[0]
    y2 = a[1]
    x3 = b[0]
    y3 = b[1]
    d_pa = (x2-x1)**2 + (y2-y1)**2
    d_pb = (x3-x1)**2 + (y3-y1)**2
    if d_pa < d_pb:
        return('A')
    elif d_pb < d_pa:
        return('B')
    else:
        return('Equal')

# %%
closer_point((1, 2), (0, 0), (5, 5))
# Out:
# 'A'

# %%
closer_point((4, 4), (0, 0), (8, 8))
# Out:
# 'Equal'

# %%
def is_point_on_line_1d(a, b, p):
    if p>=a and p <=b:
        return True
    else:
        return False

# %%
is_point_on_line_1d(2, 5, 3)
# Out:
# True

# %%
is_point_on_line_1d(4, 4, 4)  
'''are_lines_touching_or_overlapping(1, 4, 3, 6)        # Output: True   (Overlap from 3 to 4)  1,7,6,8
are_lines_touching_or_overlapping(1, 3, 3, 5)        # Output: True   (Touch at point 3)
are_lines_touching_or_overlapping(1, 2, 3, 4)        # Output: False  (Completely separate)'''
# Out:
# True

# %%
def are_lines_touching_or_overlapping(start1, end1, start2, end2):
    if (start1 <= start2 and start2 <= end1 and end1 <= end2) or (start1 <= start2 and start2 <=end1 and end1 <=end2):#overlap
        return True
    elif end1 == start2: #touch
        return True
    elif start1 < end1 and start2 < end2 and end1 != start1:
        return False

# %%
are_lines_touching_or_overlapping(1, 2, 3, 5)
# Out:
# False

# %%
def is_point_inside_rectangle(x1, y1, x2, y2, px, py):
    if (px >=x1 and py==y1) or (px > x1 and px <=x2 and py>y1 and py <=y2):
        return True
    else: 
        return False

# %%
is_point_inside_rectangle(0, 0, 10, 5, 3, 2)
# Out:
# True

# %%
is_point_inside_rectangle(0, 0, 10, 5, 10, 5)
# Out:
# True

# %%
is_point_inside_rectangle(0, 0, 10, 5, 11, 5)
# Out:
# False

# %%
def are_rectangles_intersecting(rect1: tuple, rect2: tuple):    
    x1y1 = rect1[0]
    x2y2 = rect1[1]
    x1 = x1y1[0]
    y1 = x1y1[1]
    x2= x2y2[0]
    y2 = x2y2[1]
    p1q1 = rect2[0]
    p2q2 = rect2[1]
    p1 = p1q1[0]
    q1 = p1q1[1]
    p2 = p2q2[0]
    q2 = p2q2[1]    
    if(p1 > x1 and p2 <x2 and q1>y1 and q2<y2) or ( p1>x1 and q1==y1 and p2>x2 and q2 >y2)or (x2==p1 and y2 == q1 and x2 < p2 and y2 < q2) or (p1<x2 and q1 <y2 and x2 < p2 and y2 <q2):
        return True
    else: 
        return False

# %%
are_rectangles_intersecting(((0, 0), (3, 3)), ((2, 2), (5, 5)))
# Out:
# True
