# %%
def try_guess(left, right):
    guess = (left + right)/2
    print(guess, guess*guess)

# %%
try_guess(4,6)
# Out:
# 5.0 25.0

# %%
n =5
#d*d =25
print(n**(1/2))
# Out:
# 2.23606797749979

# %%
def calsquareroot(n):
    sqrt= n**(1/2)
    print(f"Square root of {n} is {sqrt}")

# %%
calsquareroot(64)
# Out:
# Square root of 64 is 8.0

# %%
calsquareroot(6)
# Out:
# Square root of 6 is 2.449489742783178

# %%
calsquareroot(8)
# Out:
# Square root of 8 is 2.8284271247461903
